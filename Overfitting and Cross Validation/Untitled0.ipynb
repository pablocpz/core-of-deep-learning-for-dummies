# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi*3, np.pi*3, 500)

# %%
plt.plot(x, 0.4*np.sin(x)+np.cos(x)*0.04+x**0.001 + x**0.04);
# Out:
# <ipython-input-27-dabd1aa38757>:1: RuntimeWarning: invalid value encountered in power
#   plt.plot(x, 0.4*np.sin(x)+np.cos(x)*0.04+x**0.001 + x**0.04);
